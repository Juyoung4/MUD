# %%
import os, json, glob, sys, numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from numpy import nan as NA

# %%
os.chdir("C:\\Users\\zinckim\\Desktop\\cf")

data = pd.read_csv('merge11.csv') 
data.rename(columns={'년 만 의 연말 성과급 국민은행 최대 만 원 지급': 'Title'}, inplace=True)
del data['국민은행 이 올 연말 직원 들 에게 만 만 원 성과급 을 지급 하 기 로 했 다 일 금융 권 에 따르 면 국민은행 은 최근 분기 노사 협의회 에서 기본급 의 에 해당 하 는 연말 특별 보로금 을 지급 하 기 로 합의 했 다 올해 호 실적 이 확실 시 되 는 상황 이 어서 우선 기본급 의 를 지급 하 고 연말 결산 이 끝나 면 내년 초 에 잔여 금 을 주 기 로 한 것 이 다 이 에 따라 국민은행 직원 은 연말 에 만 만 만 원 의 성과급 을 받 게 됐 다 국민은행 은 년 을 마지막 으로 지난 년 간 연말 특별 성과급 을 지급 하 지 않 았 다 이 는 윤종규 금융 지주 회장 이 언급 한 초과 이익 배분 제 의 일환 으로 풀이 된다 윤 회장 은 지난 월 임직원 정기 조회 에서 땀 의 결실 인 초과 이익 을 당당 하 게 공유 할 수 있 도록 할 것 이 라며 지속 가능 한 보상 체계 로 이익 배분 제 를 합리 적 으로 재 정비 하 겠 다 고 밝힌 바 있 다']
li = []
for _ in range(len(data)):
    li.append(random.choice([1, 2, 3,1.5,2.5]))
data['Score'] = li
data['ID'] = '아연'
data.loc[5000:7000,'Score'] = 0
#print(data.iloc[:,3])

# %%
display(data.head())
print(len(data))
# Out:
#                                             Title  Score  ID
# 0            오바마 북한 같 은 불량 국가 문제 해결 에 여전히 외교 가 중요    1.0  아연
# 1              서울 경제 한 달 남 은 통신사 멤버 십 포인트 알뜰 활용 법    2.5  아연
# 2  클릭 한경 페이스북 달군 몸 의 지배자 호르몬 평가 엇갈린 넷플릭스 의 인재 관리법    2.0  아연
# 3             강간 미수범 도 화학 적 거세 법안 국회 통과 몰카 범 은 제외    1.0  아연
# 4                   넷플릭스 등 온라인 콘텐츠 에 맞 는 등급 분류 필요    2.5  아연
# 9999

# %%
os.chdir("C:\\Users\\zinckim\\Desktop\\cf")

data2 = pd.read_csv('merge11.csv') 
data2.rename(columns={'년 만 의 연말 성과급 국민은행 최대 만 원 지급': 'Title'}, inplace=True)
del data2['국민은행 이 올 연말 직원 들 에게 만 만 원 성과급 을 지급 하 기 로 했 다 일 금융 권 에 따르 면 국민은행 은 최근 분기 노사 협의회 에서 기본급 의 에 해당 하 는 연말 특별 보로금 을 지급 하 기 로 합의 했 다 올해 호 실적 이 확실 시 되 는 상황 이 어서 우선 기본급 의 를 지급 하 고 연말 결산 이 끝나 면 내년 초 에 잔여 금 을 주 기 로 한 것 이 다 이 에 따라 국민은행 직원 은 연말 에 만 만 만 원 의 성과급 을 받 게 됐 다 국민은행 은 년 을 마지막 으로 지난 년 간 연말 특별 성과급 을 지급 하 지 않 았 다 이 는 윤종규 금융 지주 회장 이 언급 한 초과 이익 배분 제 의 일환 으로 풀이 된다 윤 회장 은 지난 월 임직원 정기 조회 에서 땀 의 결실 인 초과 이익 을 당당 하 게 공유 할 수 있 도록 할 것 이 라며 지속 가능 한 보상 체계 로 이익 배분 제 를 합리 적 으로 재 정비 하 겠 다 고 밝힌 바 있 다']
li = []
for _ in range(len(data)):
    li.append(random.choice([3.5,4,4.5,5]))
data2['Score'] = li
data2['ID'] = '주영'
data.loc[:2000,'Score'] = 0
display(data2.head())
print(len(data2))
# Out:
#                                             Title  Score  ID
# 0            오바마 북한 같 은 불량 국가 문제 해결 에 여전히 외교 가 중요    4.0  주영
# 1              서울 경제 한 달 남 은 통신사 멤버 십 포인트 알뜰 활용 법    4.5  주영
# 2  클릭 한경 페이스북 달군 몸 의 지배자 호르몬 평가 엇갈린 넷플릭스 의 인재 관리법    4.0  주영
# 3             강간 미수범 도 화학 적 거세 법안 국회 통과 몰카 범 은 제외    4.5  주영
# 4                   넷플릭스 등 온라인 콘텐츠 에 맞 는 등급 분류 필요    4.0  주영
# 9999

# %%
os.chdir("C:\\Users\\zinckim\\Desktop\\cf")

data3 = pd.read_csv('merge11.csv') 
data3.rename(columns={'년 만 의 연말 성과급 국민은행 최대 만 원 지급': 'Title'}, inplace=True)
del data3['국민은행 이 올 연말 직원 들 에게 만 만 원 성과급 을 지급 하 기 로 했 다 일 금융 권 에 따르 면 국민은행 은 최근 분기 노사 협의회 에서 기본급 의 에 해당 하 는 연말 특별 보로금 을 지급 하 기 로 합의 했 다 올해 호 실적 이 확실 시 되 는 상황 이 어서 우선 기본급 의 를 지급 하 고 연말 결산 이 끝나 면 내년 초 에 잔여 금 을 주 기 로 한 것 이 다 이 에 따라 국민은행 직원 은 연말 에 만 만 만 원 의 성과급 을 받 게 됐 다 국민은행 은 년 을 마지막 으로 지난 년 간 연말 특별 성과급 을 지급 하 지 않 았 다 이 는 윤종규 금융 지주 회장 이 언급 한 초과 이익 배분 제 의 일환 으로 풀이 된다 윤 회장 은 지난 월 임직원 정기 조회 에서 땀 의 결실 인 초과 이익 을 당당 하 게 공유 할 수 있 도록 할 것 이 라며 지속 가능 한 보상 체계 로 이익 배분 제 를 합리 적 으로 재 정비 하 겠 다 고 밝힌 바 있 다']
li = []
for _ in range(len(data)):
    li.append(random.choice([3.5,4,4.5,5]))
data3['Score'] = li
data3['ID'] = '혜원'
data.loc[3000:6000,'Score'] = 0
display(data3.head())
print(len(data3))
# Out:
#                                             Title  Score  ID
# 0            오바마 북한 같 은 불량 국가 문제 해결 에 여전히 외교 가 중요    3.5  혜원
# 1              서울 경제 한 달 남 은 통신사 멤버 십 포인트 알뜰 활용 법    4.0  혜원
# 2  클릭 한경 페이스북 달군 몸 의 지배자 호르몬 평가 엇갈린 넷플릭스 의 인재 관리법    4.5  혜원
# 3             강간 미수범 도 화학 적 거세 법안 국회 통과 몰카 범 은 제외    5.0  혜원
# 4                   넷플릭스 등 온라인 콘텐츠 에 맞 는 등급 분류 필요    4.5  혜원
# 9999

# %%
os.chdir("C:\\Users\\zinckim\\Desktop\\cf")

data4 = pd.read_csv('merge11.csv') 
data4.rename(columns={'년 만 의 연말 성과급 국민은행 최대 만 원 지급': 'Title'}, inplace=True)
del data4['국민은행 이 올 연말 직원 들 에게 만 만 원 성과급 을 지급 하 기 로 했 다 일 금융 권 에 따르 면 국민은행 은 최근 분기 노사 협의회 에서 기본급 의 에 해당 하 는 연말 특별 보로금 을 지급 하 기 로 합의 했 다 올해 호 실적 이 확실 시 되 는 상황 이 어서 우선 기본급 의 를 지급 하 고 연말 결산 이 끝나 면 내년 초 에 잔여 금 을 주 기 로 한 것 이 다 이 에 따라 국민은행 직원 은 연말 에 만 만 만 원 의 성과급 을 받 게 됐 다 국민은행 은 년 을 마지막 으로 지난 년 간 연말 특별 성과급 을 지급 하 지 않 았 다 이 는 윤종규 금융 지주 회장 이 언급 한 초과 이익 배분 제 의 일환 으로 풀이 된다 윤 회장 은 지난 월 임직원 정기 조회 에서 땀 의 결실 인 초과 이익 을 당당 하 게 공유 할 수 있 도록 할 것 이 라며 지속 가능 한 보상 체계 로 이익 배분 제 를 합리 적 으로 재 정비 하 겠 다 고 밝힌 바 있 다']
li = []
for _ in range(len(data)):
    li.append(random.choice([1, 2, 3, 4, 5,1.5,2.5,3.5,4.5]))
data4['Score'] = li
data4['ID'] = '승환'
data.loc[7000:,'Score'] = 0
display(data4.head())
print(len(data4))
# Out:
#                                             Title  Score  ID
# 0            오바마 북한 같 은 불량 국가 문제 해결 에 여전히 외교 가 중요    1.0  승환
# 1              서울 경제 한 달 남 은 통신사 멤버 십 포인트 알뜰 활용 법    2.5  승환
# 2  클릭 한경 페이스북 달군 몸 의 지배자 호르몬 평가 엇갈린 넷플릭스 의 인재 관리법    4.5  승환
# 3             강간 미수범 도 화학 적 거세 법안 국회 통과 몰카 범 은 제외    1.0  승환
# 4                   넷플릭스 등 온라인 콘텐츠 에 맞 는 등급 분류 필요    3.5  승환
# 9999

# %%
os.chdir("C:\\Users\\zinckim\\Desktop\\cf")

data5 = pd.read_csv('merge11.csv') 
data5.rename(columns={'년 만 의 연말 성과급 국민은행 최대 만 원 지급': 'Title'}, inplace=True)
del data5['국민은행 이 올 연말 직원 들 에게 만 만 원 성과급 을 지급 하 기 로 했 다 일 금융 권 에 따르 면 국민은행 은 최근 분기 노사 협의회 에서 기본급 의 에 해당 하 는 연말 특별 보로금 을 지급 하 기 로 합의 했 다 올해 호 실적 이 확실 시 되 는 상황 이 어서 우선 기본급 의 를 지급 하 고 연말 결산 이 끝나 면 내년 초 에 잔여 금 을 주 기 로 한 것 이 다 이 에 따라 국민은행 직원 은 연말 에 만 만 만 원 의 성과급 을 받 게 됐 다 국민은행 은 년 을 마지막 으로 지난 년 간 연말 특별 성과급 을 지급 하 지 않 았 다 이 는 윤종규 금융 지주 회장 이 언급 한 초과 이익 배분 제 의 일환 으로 풀이 된다 윤 회장 은 지난 월 임직원 정기 조회 에서 땀 의 결실 인 초과 이익 을 당당 하 게 공유 할 수 있 도록 할 것 이 라며 지속 가능 한 보상 체계 로 이익 배분 제 를 합리 적 으로 재 정비 하 겠 다 고 밝힌 바 있 다']
li = []
for _ in range(len(data)):
    li.append(random.choice([1, 2, 3, 4, 5,1.5,2.5,3.5,4.5]))
data5['Score'] = li
data5['ID'] = '이산가'
data.loc[5000:9000,'Score'] = 0
display(data5.head())
print(len(data5))
# Out:
#                                             Title  Score   ID
# 0            오바마 북한 같 은 불량 국가 문제 해결 에 여전히 외교 가 중요    1.0  이산가
# 1              서울 경제 한 달 남 은 통신사 멤버 십 포인트 알뜰 활용 법    3.5  이산가
# 2  클릭 한경 페이스북 달군 몸 의 지배자 호르몬 평가 엇갈린 넷플릭스 의 인재 관리법    2.0  이산가
# 3             강간 미수범 도 화학 적 거세 법안 국회 통과 몰카 범 은 제외    2.5  이산가
# 4                   넷플릭스 등 온라인 콘텐츠 에 맞 는 등급 분류 필요    1.0  이산가
# 9999

# %%
df= pd.concat([data, data2, data3, data4, data5]) # row bind : axis = 0, default
df = df.reset_index(drop=True)
print(df)
# Out:
#                                                 Title  Score   ID
# 0                오바마 북한 같 은 불량 국가 문제 해결 에 여전히 외교 가 중요    0.0   아연
# 1                  서울 경제 한 달 남 은 통신사 멤버 십 포인트 알뜰 활용 법    0.0   아연
# 2      클릭 한경 페이스북 달군 몸 의 지배자 호르몬 평가 엇갈린 넷플릭스 의 인재 관리법    0.0   아연
# 3                 강간 미수범 도 화학 적 거세 법안 국회 통과 몰카 범 은 제외    0.0   아연
# 4                       넷플릭스 등 온라인 콘텐츠 에 맞 는 등급 분류 필요    0.0   아연
# 5                   세계 뉴 미디어 전문가 를 만나 다미 컬럼비아 대 타우 센터    0.0   아연
# 6                세계 뉴 미디어 전문가 를 만나 다 마크 브로 더슨 맥킨지 파트너    0.0   아연
# 7          세계 뉴 미디어 전문가 를 만나 다 멀티미디어 저널리즘 대가 헤르난데즈 교수    0.0   아연
# 8                     우 병우 불법 사찰 관여 최윤수 오늘 밤 구속 여부 결정    0.0   아연
# 9                            삼성 스포츠 사업 철수 삼성 갤럭시 팀 매각    0.0   아연
# 10                  슈퍼 컴 제 의 국력 차 산업 혁명 이끄 는 슈퍼 컴 의 힘    0.0   아연
# 11             세계 의 뉴 미디어 를 가 다 롱 폼 저널리즘 매체 크라 우트 리포터    0.0   아연
# 12                        삼성 갤럭시 에 매각 스포츠 서 손 뗀 삼성 종합    0.0   아연
# ...

# %% [markdown]
# ## data 탐색

# %%
user_num = df.ID.unique().shape[0]
news_num = df.Title.unique().shape[0]

print("유저의 수는 {}명 이고,\n영화의 수는 {}개 입니다.".format(user_num, news_num))
# Out:
# 유저의 수는 5명 이고,
# 영화의 수는 9648개 입니다.

# %% [markdown]
# ## score 랭킹

# %%
plt.style.use('ggplot')
df.Score.value_counts().plot(kind = 'bar', title = 'Score Rank',
                            figsize = (10, 5), legend = True, fontsize = 12)
plt.ylabel("Number of Scores", fontsize = 12)
plt.show()

# %%
# font_name = font_manager.FontProperties(fname = "c:/Windows/Fonts/malgun.ttf").get_name()
# rc('font', family = font_name)

# news_top_10 = df.Title.value_counts()[:10]

# plt.style.use('ggplot')
# news_top_10.plot(kind = 'bar', title = 'Movie Rank',
#                             figsize = (10, 5), legend = True, fontsize = 12)
# plt.ylabel("Number of reviews", fontsize = 12)
# plt.show()

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

from pprint import pprint

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

from sklearn.preprocessing import LabelEncoder


import pickle
import random

# %%
def execute_labeling(column_name):
    Lec = LabelEncoder()
    df_copy = df.copy()
    df_label = pd.DataFrame(Lec.fit_transform(df_copy[column_name].values), columns = [column_name+'_label'])
    return df_label

df_user = execute_labeling('ID')
df_title = execute_labeling('Title')

print(len(df_user['ID_label'].value_counts()))
print(len(df_title['Title_label'].value_counts()))


df_copy = df.copy()    # copy df

df_copy = df_copy.drop(df_copy.columns[[0, 2]], axis = 1)    # delete 'user', 'title' columns
print(df['Title'])
df_label = pd.concat([df_user, df_title,df_copy], axis = 1)    # 라벨링한 컬럼과 기존 데이터프레임 합치기

df_label.tail(5)
# Out:
# 5
# 9648
# 0                  오바마 북한 같 은 불량 국가 문제 해결 에 여전히 외교 가 중요
# 1                    서울 경제 한 달 남 은 통신사 멤버 십 포인트 알뜰 활용 법
# 2        클릭 한경 페이스북 달군 몸 의 지배자 호르몬 평가 엇갈린 넷플릭스 의 인재 관리법
# 3                   강간 미수범 도 화학 적 거세 법안 국회 통과 몰카 범 은 제외
# 4                         넷플릭스 등 온라인 콘텐츠 에 맞 는 등급 분류 필요
# 5                     세계 뉴 미디어 전문가 를 만나 다미 컬럼비아 대 타우 센터
# 6                  세계 뉴 미디어 전문가 를 만나 다 마크 브로 더슨 맥킨지 파트너
# 7            세계 뉴 미디어 전문가 를 만나 다 멀티미디어 저널리즘 대가 헤르난데즈 교수
# 8                       우 병우 불법 사찰 관여 최윤수 오늘 밤 구속 여부 결정
# 9                              삼성 스포츠 사업 철수 삼성 갤럭시 팀 매각
# 10                    슈퍼 컴 제 의 국력 차 산업 혁명 이끄 는 슈퍼 컴 의 힘
# 11               세계 의 뉴 미디어 를 가 다 롱 폼 저널리즘 매체 크라 우트 리포터
# 12                          삼성 갤럭시 에 매각 스포츠 서 손 뗀 삼성 종합
# 13                         녹십자 임원 인사 지 놈 대표 양송 현 부사장 승진
# 14                                     일동 히 알 테크 대표 강재훈
# 15                       기업 포커스 삼성 프로 게임 단 매각 스포츠 완전 철수
# 16                           네이버 카카오 규제 놓 고 정치 권 맞불 토론회
# ...

# %%
df_label.tail(5)
# Out:
#        ID_label  Title_label  Score
# 49990         2         3247    3.0
# 49991         2         5517    4.5
# 49992         2         2663    1.0
# 49993         2         6823    3.5
# 49994         2          878    4.0

# %% [markdown]
# #### (2) 유저와 영화 제목이 column이고 각 원소가 평점인 DataFrame 생성

# %%
news_list = df['nTitle'].unique()
news_list = sorted(news_list, key=str)
df_matrix = pd.DataFrame(columns = ['ID'] + news_list)
df_matrix    #결과확인
# Out:
# Empty DataFrame
# ...

# %%
# %%time

user_num = len(df_label.ID_label.unique())
news_num = len(df_label.Title_label.unique())


user_score_list = []    # df_matrix에서 'user' 컬럼을 제외한 컬럼. 즉, title 컬럼
for num in range(0, user_num):
    user_score_list = [0 for i in range(news_num)]    # 값을 0으로 초기화
    df_tmp = df_label[df_label['ID_label'] == num]    # 각 유저별로 묶는
    
    print(df_tmp.head())
    for j in df_tmp.index:
            user_score_list[int(df_tmp.ix[j]['Title_label']-1)] = df_tmp.ix[j]['Score'] # user가 평가한 영화가 있다면 score를 채워넣는다

                
    df_matrix.loc[num] = [num] + user_score_list    # 행채우기
# Out:
#        ID_label  Title_label  Score
# 29997         0         5565    1.0
# 29998         0         4212    2.5
# 29999         0         8226    4.5
# 30000         0          123    1.0
# 30001         0         1740    3.5
# C:\Users\zinckim\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if sys.path[0] == '':
#    ID_label  Title_label  Score
# 0         1         5565    0.0
# 1         1         4212    0.0
# 2         1         8226    0.0
# 3         1          123    0.0
# 4         1         1740    0.0
#        ID_label  Title_label  Score
# 39996         2         5565    1.0
# 39997         2         4212    3.5
# 39998         2         8226    2.0
# 39999         2          123    2.5
# 40000         2         1740    1.0
# ...

# %% [markdown]
# #### 피클

# %%
# 유틸리티행렬 pickle 저장
file = df_matrix
directory = open('utilitymatrix', 'wb')
pickle.dump(file, directory)
directory.close()

# %%
user_name = df['ID'].unique()
user_name = sorted(user_name, key = str)
user_name = pd.DataFrame(user_name)
user_name.columns = ['user_name']

# user_name pickle 저장
file_user = user_name
directory_user = open('user_name', 'wb')
pickle.dump(file_user, directory_user)
directory_user.close()

# %%
# pickle로 저장한 user_name data frame open
f = open('user_name', 'rb')
user_name = pickle.load(f)
user_name = user_name

# %%
# pickle로 저장한 유틸리티 행렬 DATA LOAD
f = open('utilitymatrix', 'rb')
utilitymatrix = pickle.load(f)

df = utilitymatrix
df.tail(2)
# Out:
#     ID  ㅎ ㅑㅁ샤우트 벤처 스타트업 지원 비즈니스 엑셀 러레이 션 시장 진출 선언  \
# 3  3.0                                        4.5
# 4  4.0                                        4.5
#
#    가 김연아 출연 평창 마케팅 에 발끈하 는 진짜 이유  가 깨우 고 자율 차 로 출 근년 뒤 엔 공상 아닌 일상  \
# 3                            4.0                              4.5
# 4                            4.5                              3.5
#
#    가 데이터 센터 장애 미리 막 는다  가 만든 로봇 암웨이 매장 안 내 맡 는다  \
# 3                  3.5                      3.5
# 4                  3.5                      3.5
#
#    가 미래 먹거리 이 통사 돈 되 는 사업 에 힘 싣 는다  가 산불 감 지재 난대 응 빨라진다  가 실 시간 모션 인식 쏙 보 니  \
# 3                              4.0                  4.5                 4.0
# 4                              5.0                  4.0                 3.5
#
#    가 쓰 는 데이터 특정 기업 이 독점 못 하 게 막 아야  ...  흥행 가능 성 확인 한 모바일 스포츠 내년 엔  \
# 3                              4.5  ...                        5.0
# 4                              5.0  ...                        5.0
#
# ...

# %%
df_concat = pd.concat([user_name, df], axis = 1)
df_concat.tail(5)
# Out:
#   user_name   ID  ㅎ ㅑㅁ샤우트 벤처 스타트업 지원 비즈니스 엑셀 러레이 션 시장 진출 선언  \
# 0        승환  0.0                                        1.0
# 1        아연  1.0                                        0.0
# 2       이산가  2.0                                        3.5
# 3        주영  3.0                                        4.5
# 4        혜원  4.0                                        4.5
#
#    가 김연아 출연 평창 마케팅 에 발끈하 는 진짜 이유  가 깨우 고 자율 차 로 출 근년 뒤 엔 공상 아닌 일상  \
# 0                            2.5                              3.0
# 1                            0.0                              0.0
# 2                            2.5                              1.0
# 3                            4.0                              4.5
# 4                            4.5                              3.5
#
#    가 데이터 센터 장애 미리 막 는다  가 만든 로봇 암웨이 매장 안 내 맡 는다  \
# 0                  4.0                      5.0
# 1                  0.0                      0.0
# 2                  2.0                      5.0
# ...

# %% [markdown]
# #### II. 유저(t)와 유사한 K명의 유저(s)를 찾고, 유저(t)가 아직 평가하지 않은 영화의 평점을 예측한다

# %% [markdown]
# #### 유사도척도

# %%
def cosine_similarity(data_name):    
    from sklearn.metrics.pairwise import cosine_distances
    similarity = 1 - cosine_distances(data_name)   
    return similarity

cos_sim = cosine_similarity(df)   
print(cos_sim.shape)
cos_sim
# Out:
# (5, 5)
# array([[1.        , 0.28155385, 0.84392988, 0.91034432, 0.91050704],
#        [0.28155385, 1.        , 0.27004324, 0.29473817, 0.29357397],
#        [0.84392988, 0.27004324, 1.        , 0.91026479, 0.9100971 ],
#        [0.91034432, 0.29473817, 0.91026479, 1.        , 0.98321392],
#        [0.91050704, 0.29357397, 0.9100971 , 0.98321392, 1.        ]])

# %%
#### (2) K명의 유저(s)를 이용하여 유저(t)가 예측하지 않은 영화의 평점 예측

# %%
class Basic(object):
    
    def __init__(self, user_name, neigh_num):
        self.user_name = user_name
        self.neigh_num = neigh_num
    
    """유저의 이름이 들어오면 유저 번호로 변환"""
    def convert_user_num(self):
        
        user_name_list = df_concat['user_name'].unique()
        
        for num in range(len(user_name_list)):
            if user_name_list[num] == self.user_name:
                user_num = num
        
        return user_num
    
    
    """target 유저와 유사한 유저 K명을 찾고, cosine 유사도를 이용하여 거리를 구한다"""
    def find_near_neighbor(self):
    
        from sklearn.neighbors import NearestNeighbors
        
        user_num = Basic.convert_user_num(self)
            
        KNN = NearestNeighbors(n_neighbors = self.neigh_num, metric = 'cosine')    # n_neighbors에는 본인이 포함되기 때문에 +1을 해준다.
        KNN.fit(df)    # data set은 utility matrix인 df를 사용
        similar_distance, similar_users = KNN.kneighbors(df)
    
        similars = {}    #유사한 유저와 거리를 dict형식으로 저장
    
        # 유사한 유저
        similar_users = similar_users[user_num][1:]
        similars['sim_users'] = list(similar_users)
    
        # 유사한 유저들과의 거리
        similar_distance = similar_distance[user_num][1:]
        similars['sim_distance'] = similar_distance
    
        return similars
    
    
    """target유저 + 유사한 유저 K명으로 이루어진 새로운 data frame 형성하고, narray 형식으로 반환"""
    def near_neighbors_narray(self):
    
        similars = Basic.find_near_neighbor(self)
        similiar_users_list = similars['sim_users']
        similiar_distances = similars['sim_distance']

        columns = list(df.columns)
        new_df = pd.DataFrame(columns = columns)
    
        for i in range(len(similiar_users_list)):
        
            def concat_row(i):
                neighbor_df = df[df['ID'] == similiar_users_list[i]]
                return neighbor_df
        
            neighbor_df = pd.concat([new_df, concat_row(i)])
            new_df = neighbor_df
            
        narray = new_df.values
        narray = narray[:, 1:]
        
        return narray

# %%
class Calculation_rating(Basic):
    
    def __init__(self, user_name, neigh_num):
        Basic.__init__(self, user_name, neigh_num)
        
    """가중평균 값으로 아이템에 대한 target 유저의 평점을 예측"""
    def predict_rating(self):
        
        narray = Basic.near_neighbors_narray(self)    #narray 받음
        similars = Basic.find_near_neighbor(self)
        
        similiar_distances = similars['sim_distance']
    
        rating_list = []    # 가중평균값을 담는 리스트
    
        # 범위 0 ~ K-1
        for col_num in range(narray.shape[1]):
        
            sum = 0
            rating = 0
            for i in range(1, len(narray[:, col_num])):
                 sum += float(narray[:, col_num][i]) * float(similiar_distances[i])
            rating = sum/similiar_distances.sum()
        
            if rating < 0:
                rating = 0    # 만약 가중평균값이 0보다 작으면 0점으로 함
            elif rating > 10:
                rating = 10    # 만약 가중평균값이 10보다 크면 10점으로 함
            else:
                rating = int(rating)    # 평점은 정수형
    
            rating_list.append(rating)

        return rating_list
        
    
    """target 유저의 평점을 리스트로 변환하는 함수"""
    def original_rating(self):
        
        user_num = Basic.convert_user_num(self)
    
        # target 유저의 평점을 narray로 변환
        target_df = df[df['ID'] == user_num]
        target_narray = target_df.values
        target_narray = target_narray[:, 1:]    # user column 삭제
    
        #narray로 변환된 target 유저의 평점을 리스트로 변환
        target_user_rating_list = []
        for i in range(target_narray.shape[1]):
            raw_rating = int(target_narray[0][i])
            target_user_rating_list.append(raw_rating)
    
        return target_user_rating_list

# %%
#예측 평점
user_0tae = Calculation_rating('아연', 5)
print(user_0tae.predict_rating()[100:120])
# Out:
# [2, 1, 3, 2, 1, 1, 2, 2, 1, 1, 2, 2, 3, 2, 2, 3, 3, 2, 1, 2]

# %%
#기존 평점
#0은 평가되지 않음을 의미한다
print(user_0tae.original_rating()[100:120])
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0, 2, 0, 0, 2, 0, 0, 0, 0, 3, 0, 0, 0]

# %%
# MSE를 이용한 성능평가 함수
def evaluation(neigh_num):
    
    from sklearn.metrics import mean_squared_error
    
    neigh_num = neigh_num
    rmse = 0
    user_name_list = df_concat['user_name'].unique()
    
    for user_name in user_name_list:
        
        cal = Calculation_rating(user_name, neigh_num)
        predict_list = cal.predict_rating()
        original_list = cal.original_rating()
        rmse_onebyone = mean_squared_error(original_list, predict_list)
        
        rmse += rmse_onebyone
        
    rmse = rmse/len(user_name_list)

    return print('이웃의 수가 {}일때, MSE 값은 {}입니다.'.format(neigh_num-1, rmse))

# %%
# %%time
neigh_num = [2, 3, 4, 5]
for num in neigh_num:
    evaluation(num)
# Out:
# 이웃의 수가 1일때, MSE 값은 10.43134328358209입니다.
# 이웃의 수가 2일때, MSE 값은 4.138266998341625입니다.
# 이웃의 수가 3일때, MSE 값은 3.628130182421227입니다.
# 이웃의 수가 4일때, MSE 값은 10.232960199004975입니다.
# Wall time: 31.9 s

# %%
class UBCF(Calculation_rating):
    
    def __init__ (self, user_name, neigh_num):
        Basic.__init__(self, user_name, neigh_num)
        Calculation_rating.__init__(self, user_name, neigh_num)        
        
    def recommen_news_list(self):
        
        user_num = Basic.convert_user_num(self)
        predict_list = Calculation_rating.predict_rating(self)
        original_list = Calculation_rating.original_rating(self)
        all_movie_list = list(df.columns)[1:]    # 전체 뉴스 리스트
        
 
        temp_list = []
        for i in range(len(predict_list)):
            if int(original_list[i]) != 0:
                temp_list.append(0)
            else:
                temp_list.append(int(predict_list[i]))
        
        # 4점 이상인 뉴스들만 선택하여 index를 추천 리스트에 담는다.
        recommen_list_index =[]
        for i in range(len(temp_list)):
            if temp_list[i] >= 5:
                recommen_list_index.append(i)
        
        # recommen_list_index로 부터 뉴스 제목을 str로 저장
        recommen_list_str = []
        for i in recommen_list_index:
            recommen_list_str.append(all_movie_list[i])
        
        #전체 뉴스 리스트에서 target 사용자가 이미 평가한 뉴스를 제거
        already_rating_news_num = [i for i in range(len(temp_list)) if temp_list[i] == 0]
        user_news_list = [all_news_list[i] for i in range(len(all_news_list)) if i not in already_rating_news_num]

        
        final_dict = {}
        final_dict['by_rating'] = recommen_list_str
        final_dict['by_delete'] = user_news_list
        
        return final_dict
    
    
    """영화 추천 실행 함수"""
    def recommendation(self):
        
        user_number = Basic.convert_user_num(self)
        movie_dict = UBCF.recommen_movie_list(self)
        
        by_rating_list = movie_dict['by_rating']
        by_delete_list = movie_dict['by_delete']
        
        # 만약 추천 리스트가 3개 이상이라면 가중평균 리스트에서 3편의 영화를 추천리스트에서 추천
        # 그렇지 않으면 유저가 이미 평가했던 영화를 제외한 영화 리스트에서 추천
        if len(by_rating_list) >= 3:
            recommendation_selection = random.sample(by_rating_list, 3)
        else:
            if len(by_delete_list) >= 3 :
                recommendation_selection = random.sample(by_delete_list, 3)
            else:
                recommendation_selection = random.sample(by_delete_list, 1)
            
        user_name = df_concat['user_name'][user_number]    # user number를 user의 아이디로 변경
    
        print('{}님을 위한 추천 영화 입니다.'.format(user_name))
        return print(recommendation_selection)

# %%
recommendation_0tae = UBCF('아연', 4)
recommendation_0tae.recommendation()
# Out:
# 아연님을 위한 추천 영화 입니다.
# ['휘어지 는 플렉서블 년 부터 대중 화 될 듯', '미세먼지 보다 작 은 플라스틱 의 습격 마시 는 물 도 안심 할 수 없 다', '모바일 괴물 스펙 에 알뜰 한 가격 가성 비 중저가 폰 쏟아진다']
